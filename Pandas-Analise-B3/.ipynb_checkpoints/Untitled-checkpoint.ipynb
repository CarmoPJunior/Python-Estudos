# %% [markdown]
# ### Importa as bibliotecas

# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ##### Exibe a versão do Panda

# %%
pd.__version__
# Out:
# '1.3.4'

# %% [markdown]
# ##### Carrega o Arquivo

# %%
df = pd.read_excel('movimentacao-2021-12-19-02-00-08.xlsx', sheet_name="Movimentação")

# %% [markdown]
# ##### Exibe as linhas do arquivo

# %%
df.head(30)
# Out:
#    Entrada/Saída        Data                 Movimentação  \
# 0        Credito  16/12/2021   Transferência - Liquidação
# 1        Credito  15/12/2021   Transferência - Liquidação
# 2        Credito  14/12/2021                   Rendimento
# 3        Credito  14/12/2021                   Rendimento
# 4        Credito  14/12/2021                   Rendimento
# 5        Credito  14/12/2021                   Rendimento
# 6        Credito  14/12/2021                   Rendimento
# 7        Credito  10/12/2021   Transferência - Liquidação
# 8        Credito  10/12/2021   Transferência - Liquidação
# 9         Debito  10/12/2021   Transferência - Liquidação
# 10       Credito  02/12/2021   Transferência - Liquidação
# 11       Credito  02/12/2021   Transferência - Liquidação
# 12       Credito  01/12/2021   Transferência - Liquidação
# 13        Debito  01/12/2021   Transferência - Liquidação
# 14       Credito  30/11/2021  Juros Sobre Capital Próprio
# 15       Credito  29/11/2021   Transferência - Liquidação
# 16       Credito  26/11/2021  Juros Sobre Capital Próprio
# 17       Credito  24/11/2021   Transferência - Liquidação
# 18       Credito  22/11/2021                   Rendimento
# 19       Credito  18/11/2021   Transferência - Liquidação
# 20       Credito  16/11/2021                   Rendimento
# 21       Credito  16/11/2021                   Rendimento
# 22       Credito  16/11/2021                   Rendimento
# 23       Credito  16/11/2021                   Rendimento
# 24       Credito  16/11/2021                   Rendimento
# 25       Credito  12/11/2021   Transferência - Liquidação
# 26       Credito  12/11/2021   Transferência - Liquidação
# 27       Credito  12/11/2021   Transferência - Liquidação
# 28       Credito  12/11/2021   Transferência - Liquidação
# 29       Credito  26/10/2021   Transferência - Liquidação
#
#                                               Produto  \
# 0                         BTCR11       - FII BTG CRI
# 1                           CSAN3        - COSAN S.A.
# 2   BCFF11       - FDO INV IMOB - FII BTG PACTUAL ...
# 3   BRCR11       - FDO INV IMOB - FII BTG PACTUAL ...
# 4                         BTCR11       - FII BTG CRI
# 5   MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
# 6   SADI11       - SANTANDER PAPÉIS IMOBILIÁRIOS C...
# 7                   MGLU3        - MAGAZINE LUIZA S/A
# 8   MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
# 9          UGPA3        - ULTRAPAR PARTICIPACOES S.A.
# 10                        BTCR11       - FII BTG CRI
# 11  MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
# 12                          CIEL3        - CIELO S.A.
# 13  XPHT11       - XP HOTÉIS - FII- FII (VRE HOTEI...
# 14                 BBAS3        - BANCO DO BRASIL S/A
# 15                          CIEL3        - CIELO S.A.
# 16                          CIEL3        - CIELO S.A.
# 17                          CIEL3        - CIELO S.A.
# 18                        WTSP11B      - FII WTC SP
# 19                          CIEL3        - CIELO S.A.
# 20  BCFF11       - FDO INV IMOB - FII BTG PACTUAL ...
# 21  BRCR11       - FDO INV IMOB - FII BTG PACTUAL ...
# 22                        BTCR11       - FII BTG CRI
# 23  MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
# 24  SADI11       - SANTANDER PAPÉIS IMOBILIÁRIOS C...
# 25                          CIEL3        - CIELO S.A.
# 26                  MGLU3        - MAGAZINE LUIZA S/A
# 27  MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
# 28                             WEGE3        - WEG S/A
# 29  MXRF11       - MAXI RENDA FUNDO DE INVESTIMENT...
#
#                    Instituição  Quantidade Preço unitário Valor da Operação
# 0   CLEAR CORRETORA - GRUPO XP           3          89.99            269.97
# 1   CLEAR CORRETORA - GRUPO XP          10          22.37             223.7
# 2   CLEAR CORRETORA - GRUPO XP          12            0.5                 6
# 3   CLEAR CORRETORA - GRUPO XP           2            0.5                 1
# 4   CLEAR CORRETORA - GRUPO XP          17            0.9              15.3
# 5   CLEAR CORRETORA - GRUPO XP          17           0.08              1.36
# 6   CLEAR CORRETORA - GRUPO XP           2           0.59              1.18
# 7   CLEAR CORRETORA - GRUPO XP          20           6.86             137.2
# 8   CLEAR CORRETORA - GRUPO XP          18            9.9             178.2
# 9   CLEAR CORRETORA - GRUPO XP          25           15.3             382.5
# 10  CLEAR CORRETORA - GRUPO XP           5          89.96             449.8
# 11  CLEAR CORRETORA - GRUPO XP           2          10.03             20.06
# 12  CLEAR CORRETORA - GRUPO XP          65           2.11            137.15
# 13  CLEAR CORRETORA - GRUPO XP           5          92.55            462.77
# 14  CLEAR CORRETORA - GRUPO XP          33           0.39             11.05
# 15  CLEAR CORRETORA - GRUPO XP          28           2.18             61.04
# 16  CLEAR CORRETORA - GRUPO XP         109           0.03              2.56
# 17  CLEAR CORRETORA - GRUPO XP          42           2.19             91.98
# 18  CLEAR CORRETORA - GRUPO XP           2            0.4               0.8
# 19  CLEAR CORRETORA - GRUPO XP           9           2.35             21.15
# 20  CLEAR CORRETORA - GRUPO XP          12            0.5                 6
# 21  CLEAR CORRETORA - GRUPO XP           2           0.46              0.92
# 22  CLEAR CORRETORA - GRUPO XP          12            0.8               9.6
# 23  CLEAR CORRETORA - GRUPO XP          11           0.09              0.99
# 24  CLEAR CORRETORA - GRUPO XP           2           0.51              1.02
# 25  CLEAR CORRETORA - GRUPO XP          15           2.49             37.35
# 26  CLEAR CORRETORA - GRUPO XP          12          13.25               159
# 27  CLEAR CORRETORA - GRUPO XP           4           9.97             39.88
# 28  CLEAR CORRETORA - GRUPO XP          10          36.52             365.2
# 29  CLEAR CORRETORA - GRUPO XP           4          10.04             40.16

# %% [markdown]
# ##### Exibe as Colunas do Arquivo

# %%
df.columns
# Out:
# Index(['Entrada/Saída', 'Data', 'Movimentação', 'Produto', 'Instituição',
#        'Quantidade', 'Preço unitário', 'Valor da Operação'],
#       dtype='object')

# %% [markdown]
# ##### Exibe os tipos de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Entrada/Saída      214 non-null    object
#  1   Data               214 non-null    object
#  2   Movimentação       214 non-null    object
#  3   Produto            214 non-null    object
#  4   Instituição        214 non-null    object
#  5   Quantidade         214 non-null    int64
#  6   Preço unitário     214 non-null    object
#  7   Valor da Operação  214 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 13.5+ KB

# %% [markdown]
# ##### Trata os dados das colunas ('Preço unitário', 'Valor da Operação')

# %%
df['Preço unitário'] = df['Preço unitário'].apply(lambda x : str(x).replace("-", "0"))
df['Valor da Operação'] = df['Valor da Operação'].apply(lambda x : str(x).replace("-", "0"))

# %% [markdown]
# ##### Converte as colunas ('Preço unitário', 'Valor da Operação') para o float

# %%
df['Preço unitário'] =df['Preço unitário'].astype('float64')
df['Valor da Operação'] =df['Valor da Operação'].astype('float64')

# %% [markdown]
# ##### Converte a coluna ('Data') para o tipo Date

# %%
# df['Data'] = pd.to_datetime(df['Data'],format='%d%m%Y')
df['Data'] = pd.to_datetime(df['Data'], infer_datetime_format=True)
df['Data']
# Out:
# 0     2021-12-16
# 1     2021-12-15
# 2     2021-12-14
# 3     2021-12-14
# 4     2021-12-14
#          ...
# 209   2021-01-15
# 210   2021-01-15
# 211   2021-01-15
# 212   2021-01-08
# 213   2021-01-06
# Name: Data, Length: 214, dtype: datetime64[ns]

# %% [markdown]
# ##### Count

# %%
df.count()
# Out:
# Entrada/Saída        214
# Data                 214
# Movimentação         214
# Produto              214
# Instituição          214
# Quantidade           214
# Preço unitário       214
# Valor da Operação    214
# dtype: int64

# %% [markdown]
# ##### Discribe

# %%
df.describe()
# Out:
#        Quantidade  Preço unitário  Valor da Operação
# count  214.000000      214.000000         214.000000
# mean    10.728972       21.682804         139.256495
# std     14.538968       29.210406         165.097887
# min      0.000000        0.000000           0.000000
# 25%      3.000000        0.460000           1.635000
# 50%      7.500000       10.035000          70.500000
# 75%     12.000000       29.780000         261.905000
# max    109.000000      114.370000         789.750000

# %% [markdown]
# ##### Remove a coluna "Instituição" e exibe

# %%
df.drop(['Instituição'], axis=1, inplace=True)

# %% [markdown]
# ##### Agrupa por movimentação

# %%
df_sum_Movimentacao = df.groupby(["Movimentação"]).sum()  
df_sum_Movimentacao
# Out:
#                                        Quantidade  Preço unitário  \
# Movimentação
# Desdobro                                       27            0.00
# Direito de Subscrição                           3            0.00
# Direitos de Subscrição - Não Exercido           0            0.00
# Dividendo                                      58            0.79
# Juros Sobre Capital Próprio                   348            2.42
# Rendimento                                    406           27.15
# Transferência - Liquidação                   1454         4609.76
#
#                                        Valor da Operação
# Movimentação
# Desdobro                                            0.00
# Direito de Subscrição                               0.00
# Direitos de Subscrição - Não Exercido               0.00
# Dividendo                                          12.02
# Juros Sobre Capital Próprio                        38.12
# Rendimento                                        192.93
# Transferência - Liquidação                      29557.82

# %% [markdown]
# ##### Filtra as inforamções da coluna movimenteções

# %%
tipos_movimentacoes = ['Juros Sobre Capital Próprio','Rendimento', 'Dividendo']
df_filter_movimentacao = df[df['Movimentação'].isin(tipos_movimentacoes)]
print(df_filter_movimentacao.sum());
# Out:
# Entrada/Saída        CreditoCreditoCreditoCreditoCreditoCreditoCred...
# Movimentação         RendimentoRendimentoRendimentoRendimentoRendim...
# Produto              BCFF11       - FDO INV IMOB - FII BTG PACTUAL ...
# Quantidade                                                         812
# Preço unitário                                                   30.36
# Valor da Operação                                               243.07
# dtype: object

# %% [markdown]
# ##

# %% [markdown]
# ##### Groupby mes

# %%
#df_filter_movimentacao.groupby([df['Data'].dt.year.rename('Ano'), df['Data'].dt.month.rename('Mes'), df['Movimentação']]).sum()  

df_filter_movimentacao.groupby([df['Data'].dt.year.rename('Ano'), df['Data'].dt.month.rename('Mes')]).sum()
# Out:
#           Quantidade  Preço unitário  Valor da Operação
# Ano  Mes
# 2021 1            28            1.92              13.57
#      2            78            2.00              16.42
#      3            53            3.08              21.70
#      4            38            2.24              16.95
#      5            51            2.47              16.17
#      6            46            2.55              17.65
#      7            28            2.21              14.73
#      8           168            2.94              30.88
#      9            61            2.67              21.16
#      10           28            2.53              16.06
#      11          183            3.18              32.94
#      12           50            2.57              24.84
